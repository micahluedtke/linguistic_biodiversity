# %%
import pandas as pd

# %%
tab1 = pd.read_csv('../language_data/amano_tab1.csv')

# %%
tab2 = pd.read_csv('../language_data/amano_tab2.csv')

# %%
tab3 = pd.read_csv('../language_data/amano_tab3.csv')

# %%
tab4 = pd.read_csv('../language_data/amano_tab4.csv')

# %%
unesco = pd.read_csv('../language_data/unesco_atlas_languages_limited_dataset.csv')

# %%
wals = pd.read_csv('../language_data/wals_full_language.csv')

# %%
unesco.shape
# Out:
# (2724, 6)

# %%
wals.shape
# Out:
# (2679, 202)

# %%
wals.head()
# Out:
#   wals_code iso_code glottocode              Name   latitude   longitude  \
# 0       aab      NaN        NaN     Arapesh (Abu)  -3.450000  142.950000
# 1       aar      aiw   aari1239              Aari   6.000000   36.583333
# 2       aba      aau   abau1245              Abau  -4.000000  141.250000
# 3       abb      shu   chad1249  Arabic (Chadian)  13.833333   20.833333
# 4       abd      abi   abid1235            Abidji   5.666667   -4.583333
#
#             genus        family  macroarea countrycodes  ...  \
# 0  Kombio-Arapesh    Torricelli        NaN           PG  ...
# 1    South Omotic  Afro-Asiatic     Africa           ET  ...
# 2     Upper Sepik         Sepik  Papunesia           PG  ...
# 3         Semitic  Afro-Asiatic     Africa           TD  ...
# 4             Kwa   Niger-Congo     Africa           CI  ...
#
#   137B M in Second Person Singular 136B M in First Person Singular  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
#
#   109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
#
#   25B Zero Marking of A and P Arguments  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   21B Exponence of Tense-Aspect-Mood Inflection  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   108B Productivity of the Antipassive Construction  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   58B Number of Possessive Nouns 79B Suppletion in Imperatives and Hortatives
# 0                            NaN                                          NaN
# 1                            NaN                                          NaN
# 2                            NaN                                          NaN
# 3                            NaN                                          NaN
# 4                            NaN                                          NaN
#
# [5 rows x 202 columns]

# %%
unesco.head()
# Out:
#      ID             Name in English     Countries Country codes alpha 3  \
# 0  1444                     !Gan!ne  South Africa                   ZAF
# 1    78                     'Ongota      Ethiopia                   ETH
# 2  1882  A'ingae / Cofan (Colombia)      Colombia                   COL
# 3  1835   A'ingae / Cofan (Ecuador)       Ecuador                   ECU
# 4  1177                      A'tong         India                   IND
#
#   ISO639-3 codes Degree of endangerment
# 0            kqu                Extinct
# 1            bxe  Critically endangered
# 2            con    Severely endangered
# 3            con  Definitely endangered
# 4            aot    Severely endangered

# %%
wals.shape
# Out:
# (2000, 14)

# %%
tab1.head(20)
# Out:
#               X          Y  LandArea  TotalLanguageRichness  \
# 0  -17271041.97  7236470.1       NaN                      0
# 1  -17078069.44  7236470.1       NaN                      0
# 2  -16885096.90  7236470.1       NaN                      0
# 3  -16692124.36  7236470.1       NaN                      0
# 4  -16499151.83  7236470.1       NaN                      0
# 5  -16306179.29  7236470.1       NaN                      0
# 6  -16113206.76  7236470.1       NaN                      0
# 7  -15920234.22  7236470.1       NaN                      0
# 8  -15727261.68  7236470.1       NaN                      0
# 9  -15534289.15  7236470.1       NaN                      0
# 10 -15341316.61  7236470.1       NaN                      0
# 11 -15148344.08  7236470.1       NaN                      0
# 12 -14955371.54  7236470.1       NaN                      0
# 13 -14762399.00  7236470.1       NaN                      0
# 14 -14569426.47  7236470.1       NaN                      0
# 15 -14376453.93  7236470.1       NaN                      0
# 16 -14183481.40  7236470.1       NaN                      0
# 17 -13990508.86  7236470.1       NaN                      0
# 18 -13797536.32  7236470.1       NaN                      0
# 19 -13604563.79  7236470.1       NaN                      0
#
#     ThreatenedLanguageRichness  ExtinctLanguageRichness  ProportionThreatened  \
# 0                            0                        0                   NaN
# 1                            0                        0                   NaN
# 2                            0                        0                   NaN
# 3                            0                        0                   NaN
# 4                            0                        0                   NaN
# 5                            0                        0                   NaN
# 6                            0                        0                   NaN
# 7                            0                        0                   NaN
# 8                            0                        0                   NaN
# 9                            0                        0                   NaN
# 10                           0                        0                   NaN
# 11                           0                        0                   NaN
# 12                           0                        0                   NaN
# 13                           0                        0                   NaN
# 14                           0                        0                   NaN
# 15                           0                        0                   NaN
# 16                           0                        0                   NaN
# 17                           0                        0                   NaN
# 18                           0                        0                   NaN
# 19                           0                        0                   NaN
#
#     ProportionExtinct
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN

# %%
tab1.isnull().sum()
# Out:
# X                                0
# Y                                0
# LandArea                      8058
# TotalLanguageRichness            0
# ThreatenedLanguageRichness       0
# ExtinctLanguageRichness          0
# ProportionThreatened          9006
# ProportionExtinct             9006
# dtype: int64

# %%
tab1.shape
# Out:
# (13680, 8)

# %%
tab2.head()
# Out:
#    Longitude   Latitude            X          Y  MedianRangeSize  \
# 0       -179  81.855797 -17271041.97  7236470.1              NaN
# 1       -177  81.855797 -17078069.44  7236470.1              NaN
# 2       -175  81.855797 -16885096.90  7236470.1              NaN
# 3       -173  81.855797 -16692124.36  7236470.1              NaN
# 4       -171  81.855797 -16499151.83  7236470.1              NaN
#
#    MedianPopulationSize  MedianGrowthRate  AMT  AP  TS  ...  \
# 0                   NaN               NaN  NaN NaN NaN  ...
# 1                   NaN               NaN  NaN NaN NaN  ...
# 2                   NaN               NaN  NaN NaN NaN  ...
# 3                   NaN               NaN  NaN NaN NaN  ...
# 4                   NaN               NaN  NaN NaN NaN  ...
#
#    VegetationProductivity  ElevationRange  HabitatDiversity  \
# 0                     NaN             NaN               NaN
# 1                     NaN             NaN               NaN
# 2                     NaN             NaN               NaN
# 3                     NaN             NaN               NaN
# 4                     NaN             NaN               NaN
#
#    MeanPopulationDensity  PopulationChange  GDPpercapita  LanguageRichness  \
# 0                    NaN               NaN           NaN                 0
# 1                    NaN               NaN           NaN                 0
# 2                    NaN               NaN           NaN                 0
# 3                    NaN               NaN           NaN                 0
# 4                    NaN               NaN           NaN                 0
#
#    No.LanguagesWithGrowthEstimates  LandArea  LandAreaBand
# 0                              NaN       NaN   1080453.875
# 1                              NaN       NaN   1080453.875
# 2                              NaN       NaN   1080453.875
# 3                              NaN       NaN   1080453.875
# 4                              NaN       NaN   1080453.875
#
# [5 rows x 21 columns]

# %%
tab2.shape
# Out:
# (13680, 21)

# %%
tab2.isnull().sum()
# Out:
# Longitude                              0
# Latitude                               0
# X                                      0
# Y                                      0
# MedianRangeSize                     9006
# MedianPopulationSize                9006
# MedianGrowthRate                   11432
# AMT                                 8617
# AP                                  8581
# TS                                  8617
# PS                                  8581
# VegetationProductivity              8617
# ElevationRange                      8581
# HabitatDiversity                    8581
# MeanPopulationDensity               8700
# PopulationChange                    8602
# GDPpercapita                        8636
# LanguageRichness                       0
# No.LanguagesWithGrowthEstimates     9006
# LandArea                            8058
# LandAreaBand                           0
# dtype: int64

# %%
tab3.head()
# Out:
#   Language ISO  Initial population size  Last population size  Growth rates  \
# 0          aaa                     9000                  9000           NaN
# 1          aar                    50000               1078200      1.042475
# 2          abm                     3850                 12500           NaN
# 3          abr                   791200               1182000      1.027596
# 4          abt                    33000                 44000           NaN
#
#       Range size
# 0     236.372739
# 1  133875.794300
# 2     165.947457
# 3   14625.369870
# 4    1140.817591

# %%
tab3.shape
# Out:
# (1075, 5)

# %%
tab4.head()
# Out:
#   Language ISO  Population size   Range size
# 0          aaa           9000.0   236.372739
# 1          aab           7000.0    39.495792
# 2          aac             50.0  1102.255128
# 3          aad            830.0    63.460643
# 4          aae          80000.0   591.833327

# %%
tab4.shape
# Out:
# (6708, 3)

# %%
print(tab1.shape,
tab2.shape,
tab3.shape,
tab4.shape)
# Out:
# (13680, 8) (13680, 21) (1075, 5) (6708, 3)

# %%
tab12 = pd.merge(tab1, tab2, how='outer')

# %%
tab12.head()
# Out:
#              X          Y  LandArea  TotalLanguageRichness  \
# 0 -17271041.97  7236470.1       NaN                      0
# 1 -17078069.44  7236470.1       NaN                      0
# 2 -16885096.90  7236470.1       NaN                      0
# 3 -16692124.36  7236470.1       NaN                      0
# 4 -16499151.83  7236470.1       NaN                      0
#
#    ThreatenedLanguageRichness  ExtinctLanguageRichness  ProportionThreatened  \
# 0                           0                        0                   NaN
# 1                           0                        0                   NaN
# 2                           0                        0                   NaN
# 3                           0                        0                   NaN
# 4                           0                        0                   NaN
#
#    ProportionExtinct  Longitude   Latitude  ...  PS  VegetationProductivity  \
# 0                NaN       -179  81.855797  ... NaN                     NaN
# 1                NaN       -177  81.855797  ... NaN                     NaN
# 2                NaN       -175  81.855797  ... NaN                     NaN
# 3                NaN       -173  81.855797  ... NaN                     NaN
# 4                NaN       -171  81.855797  ... NaN                     NaN
#
#    ElevationRange  HabitatDiversity  MeanPopulationDensity  PopulationChange  \
# 0             NaN               NaN                    NaN               NaN
# 1             NaN               NaN                    NaN               NaN
# 2             NaN               NaN                    NaN               NaN
# 3             NaN               NaN                    NaN               NaN
# 4             NaN               NaN                    NaN               NaN
#
#    GDPpercapita  LanguageRichness  No.LanguagesWithGrowthEstimates  \
# 0           NaN                 0                              NaN
# 1           NaN                 0                              NaN
# 2           NaN                 0                              NaN
# 3           NaN                 0                              NaN
# 4           NaN                 0                              NaN
#
#    LandAreaBand
# 0   1080453.875
# 1   1080453.875
# 2   1080453.875
# 3   1080453.875
# 4   1080453.875
#
# [5 rows x 26 columns]

# %%
tab34 = pd.merge(tab3, tab4, how='outer')

# %%
tab34.head()
# Out:
#   Language ISO  Initial population size  Last population size  Growth rates  \
# 0          aaa                   9000.0                9000.0           NaN
# 1          aar                  50000.0             1078200.0      1.042475
# 2          abm                   3850.0               12500.0           NaN
# 3          abr                 791200.0             1182000.0      1.027596
# 4          abt                  33000.0               44000.0           NaN
#
#       Range size  Population size
# 0     236.372739           9000.0
# 1  133875.794300        1078200.0
# 2     165.947457          12500.0
# 3   14625.369870        1182000.0
# 4    1140.817591          44000.0

# %%
tab12.isnull().sum()
# Out:
# X                                      0
# Y                                      0
# LandArea                            8058
# TotalLanguageRichness                  0
# ThreatenedLanguageRichness             0
# ExtinctLanguageRichness                0
# ProportionThreatened                9006
# ProportionExtinct                   9006
# Longitude                              0
# Latitude                               0
# MedianRangeSize                     9006
# MedianPopulationSize                9006
# MedianGrowthRate                   11432
# AMT                                 8617
# AP                                  8581
# TS                                  8617
# PS                                  8581
# VegetationProductivity              8617
# ElevationRange                      8581
# HabitatDiversity                    8581
# MeanPopulationDensity               8700
# PopulationChange                    8602
# GDPpercapita                        8636
# LanguageRichness                       0
# No.LanguagesWithGrowthEstimates     9006
# LandAreaBand                           0
# dtype: int64

# %%
tab34.isnull().sum()
# Out:
# Language ISO                  1
# Initial population size    5702
# Last population size       5702
# Growth rates               6128
# Range size                  418
# Population size             208
# dtype: int64

# %%
tab12.reindex(labels=tab12.)
