# %% [markdown]
# # Biodiversity

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gpd.read_file('../biodiversity_data/resource.csv')
# Out:
#          _id                                           Biome Block  \
# 0          1             Temperate Broadleaf & Mixed Forests     1
# 1          2             Temperate Broadleaf & Mixed Forests     1
# 2          3             Temperate Broadleaf & Mixed Forests     2
# 3          4             Temperate Broadleaf & Mixed Forests     2
# 4          5             Temperate Broadleaf & Mixed Forests     3
# 5          6             Temperate Broadleaf & Mixed Forests     3
# 6          7             Temperate Broadleaf & Mixed Forests     4
# 7          8             Temperate Broadleaf & Mixed Forests     4
# 8          9             Temperate Broadleaf & Mixed Forests     1
# 9         10             Temperate Broadleaf & Mixed Forests     1
# 10        11             Temperate Broadleaf & Mixed Forests     2
# 11        12             Temperate Broadleaf & Mixed Forests     2
# 12        13             Temperate Broadleaf & Mixed Forests     3
# ...
