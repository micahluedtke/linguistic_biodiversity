# %%
import pandas as pd
import geopandas as gpd
import geopy
import seaborn as sns
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon 
import numpy as np


from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical


# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
endangered = gpd.read_file('../02_data/04_language_data/guardian_language_shp/')

# %%
endangered[endangered['Country co'].str.contains('KE') == True]
# Out:
#        ID Name in En                           Countries Country co  \
# 176    96       Suba  Kenya, United Republic of Tanzania   KEN, TZA
# 615    91      Burji                               Kenya        KEN
# 836    99       Boni                               Kenya        KEN
# 1152   95    Bong'om                               Kenya        KEN
# 1458  101     Dahalo                               Kenya        KEN
# 1653  102     Ongamo                               Kenya        KEN
# 1911   98     Omotik                               Kenya        KEN
# 2345   92     Elmolo                               Kenya        KEN
# 2392  137     Kinare                               Kenya        KEN
# 2395  100       Kore                               Kenya        KEN
# 2415   93    Lorkoti                               Kenya        KEN
# 2524   94      Yaaku                               Kenya        KEN
# 2679   97      Sogoo                               Kenya        KEN
#
#      ISO639-3 c              Degree of                 Alternate Number of  \
# 176    sxb, ssc             Vulnerable                      None    100000
# 615         bji             Vulnerable                      None      7000
# 836         bob  Definitely endangered  Aweera, Waata, Sanye\n\n      3000
# 1152        spy  Definitely endangered                      None      1000
# 1458        dal    Severely endangered                      None       400
# 1653        nsg  Critically endangered                     Nagza       200
# 1911        omt  Critically endangered                   Laamoot        50
# 2345        elo                Extinct                      None         0
# 2392       None                Extinct                      None         0
# 2395       None                Extinct                      None         0
# 2415       None                Extinct                      None         0
# 2524        muu                Extinct                  Mukogodo         0
# 2679        oki                Extinct                     Okiek      None
#
#                                Sources Latitude Longitude  \
# 176                       Okoth Okombo  -0.9942    34.519
# 615                         Ethnologue   2.1857   37.9248
# 836                        Bernd Heine  -0.8294   40.8142
# 1152                              None   1.1315   35.0134
# 1458          Mauro Tosco, Ed Elderkin  -2.2625   40.7537
# 1653                  Christoph Winter   -2.932   37.4853
# 1911        Franz Rottland, Ethnologue   -1.115   35.9143
# 2345                       Bernd Heine   2.7212   36.7326
# 2392                    Franz Rottland   -0.725   37.2436
# 2395                       Bernd Heine  -2.2845   40.9185
# 2415                    Franz Rottland  -0.4943    37.359
# 2524  Bernd Heine, Matthias Brenzinger   0.4394   37.1777
# 2679                    Franz Rottland  -1.0435   36.6006
#
#                                              Descriptio Country continent  \
# 176                                  Kenya and Tanzania   Kenya    Africa
# 615                                                None   Kenya    Africa
# 836                         Somalia-Kenyan border area.   Kenya    Africa
# 1152                    Near the Ugandan-Kenyan border.   Kenya    Africa
# 1458               Near of the mouth of the Tana river.   Kenya    Africa
# 1653  Along the Tanzanian-Kenyan border, next to the...   Kenya    Africa
# 1911                                               None   Kenya    Africa
# 2345                                               None   Kenya    Africa
# 2392                                               None   Kenya    Africa
# 2395                Last speaker  lived on Lamu Island.       0         0
# 2415                                               None   Kenya    Africa
# 2524                                               None   Kenya    Africa
# 2679                                               None   Kenya    Africa
#
#                      geometry
# 176    POINT (34.519 -0.9942)
# 615    POINT (37.9248 2.1857)
# 836   POINT (40.8142 -0.8294)
# 1152   POINT (35.0134 1.1315)
# 1458  POINT (40.7537 -2.2625)
# 1653   POINT (37.4853 -2.932)
# 1911   POINT (35.9143 -1.115)
# 2345   POINT (36.7326 2.7212)
# 2392   POINT (37.2436 -0.725)
# 2395  POINT (40.9185 -2.2845)
# 2415   POINT (37.359 -0.4943)
# 2524   POINT (37.1777 0.4394)
# 2679  POINT (36.6006 -1.0435)
